# %%
import torch
import torch.nn as nn
from torch.nn import Parameter
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Making an LSTM from scratch
#
# ### To start you will be filling in the blanks to create your own LSTM.
# ### Here are the equations you will need:
#
# $f_t=σ(W_{fx}\cdot x_t+W_{fh}\cdot h_t+b_f)$
#
# $i_t=σ(W_{ix}\cdot x_t+W_{ih}\cdot h_t+b_i)$
#
# $\tilde c_t=tanh(W_{cx}\cdot x_t+W_{ch}\cdot h_t+b_c)$
#
# $o_t=σ(W_{ox}\cdot x_t+W_{oh}\cdot h_t+b_o)$
#
# $C_t=f_t∗C_t+i_t∗\tilde c_t$
#
# $h_t=o_t∗tanh(C_t)$
#
# ### and here are the matrix and vector sizes you will need to know:
#
# $H$ = size of hidden state, $I$ = size of input features
#
# $f_t,i_t,\tilde c_t,o_t,h_t,C_t = H \times 1$
#
# $x_t = I \times 1$
#
# $W_{fx},W_{ix},W_{cx},W_{ox} = H \times I$
#
# $W_{fh},W_{ih},W_{ch},W_{oh} = H \times H$
#
# $b_{f},b_{i},b_{c},b_{o} = H \times 1$

# %%
class LSTM(nn.Module):
    def __init__(self,inputsz,hiddensz):
        super().__init__()
        self.inputsz=inputsz
        self.hiddensz=hiddensz
                
        #input gate
        self.Wix =  Parameter(torch.zeros(hiddensz, inputsz)) ##################### TO DO #####################
        self.Wih = Parameter(torch.zeros(hiddensz, hiddensz)) ##################### TO DO #####################
        self.bi = Parameter(torch.zeros(hiddensz, 1)) ##################### TO DO #####################
        
        #forget gate
        self.Wfx =  Parameter(torch.zeros(hiddensz, inputsz)) ##################### TO DO #####################
        self.Wfh = Parameter(torch.zeros(hiddensz, hiddensz)) ##################### TO DO #####################
        self.bf = Parameter(torch.zeros(hiddensz, 1)) ##################### TO DO #####################
        
        #c gate
        self.Wcx =  Parameter(torch.zeros(hiddensz, inputsz)) ##################### TO DO #####################
        self.Wch = Parameter(torch.zeros(hiddensz, hiddensz)) ##################### TO DO #####################
        self.bc = Parameter(torch.zeros(hiddensz, 1)) ##################### TO DO #####################
        
        #output gate
        self.Wox =  Parameter(torch.zeros(hiddensz, inputsz)) ##################### TO DO #####################
        self.Woh = Parameter(torch.zeros(hiddensz, hiddensz)) ##################### TO DO #####################
        self.bo = Parameter(torch.zeros(hiddensz, 1)) ##################### TO DO #####################
        
        #paramter initialization
        for p in self.parameters():  
            if p.data.ndimension()>=2:
                nn.init.xavier_uniform_(p.data)
            else:
                nn.init.zeros_(p.data)
                
    def forward(self,x,initstates=None):
        m = len(x)
        hidden_seq = []
        #print(f"hiddensz {self.hiddensz}, inputsz {self.inputsz}")
        if initstates is None:
            ht,ct = torch.zeros(self.hiddensz, 1), torch.zeros(self.hiddensz, 1)
        else:
            ht,ct = initstates
        for t in range(m):
            xt = x[t,:]
            #print(f"Wix {self.Wix.shape}, xt {xt.shape}, Wih {self.Wih.shape}, ht {ht.shape}, bi {self.bi.shape}")
            it =   torch.sigmoid(self.Wix @ xt + self.Wih @ ht + self.bi)
            ft =   torch.sigmoid(self.Wfx @ xt + self.Wfh @ ht + self.bf)
            gt =   torch.tanh(self.Wcx @ xt + self.Wch @ ht + self.bc)
            ot =   torch.sigmoid(self.Wox @ xt + self.Woh @ ht + self.bo)
            
            ct =   ft * ct + xt * gt
            ht =   ot * torch.tanh(ct)
            
            hidden_seq.append(ht.unsqueeze(0))
        hidden_seq = torch.cat(hidden_seq,dim=0)
        return hidden_seq, (ht,ct)

# %%
class customDataset(Dataset):

    def __init__(self, x, transform=None):
        self.data = x
        

    def __len__(self):
        return len(self.data)

    def __getitem__(self, i):
        return self.data[i]

# %% [markdown]
# # Addition
#
# ### First we are going to be teaching the LSTM to do addition.

# %%
def addData(size):
    size = np.random.choice(range(size,size+int(size/10)))
    inputs = torch.Tensor([[np.random.uniform(-.5,.5),0] for i in range(size)])
    choice1 = np.random.choice(range(1,10))
    choice2 = list(range(1,int(size/2)))
    choice2.remove(choice1)
    choice2 = np.random.choice(choice2)
    inputs[choice1,1]=1
    inputs[choice2,1]=1
    label = inputs[:,0][inputs[:,1]==1].sum()
    return inputs,label

# %% [markdown]
# ### Here's a look at the data. The goal is to learn to add the numbers in the left row that have a corresponding 1 in the right row while ignoring the rest.

# %%
addData(20)
# Out:
# (tensor([[ 0.4449,  0.0000],
#          [-0.4142,  0.0000],
#          [-0.3520,  0.0000],
#          [ 0.3419,  1.0000],
#          [-0.1307,  0.0000],
#          [-0.2088,  0.0000],
#          [ 0.1430,  0.0000],
#          [ 0.4426,  0.0000],
#          [-0.4021,  0.0000],
#          [-0.3655,  1.0000],
#          [-0.4092,  0.0000],
#          [ 0.2786,  0.0000],
#          [ 0.1713,  0.0000],
#          [ 0.4044,  0.0000],
#          [-0.0672,  0.0000],
#          [-0.0899,  0.0000],
#          [-0.2559,  0.0000],
#          [-0.1212,  0.0000],
#          [-0.1179,  0.0000],
#          [-0.0383,  0.0000],
#          [ 0.2305,  0.0000]]), tensor(-0.0235))

# %%
size = 20

train = customDataset([addData(size) for i in range(20)])
train_loader = DataLoader(train,batch_size = 1, shuffle = False)

val = customDataset([addData(size) for i in range(20)])
val_loader = DataLoader(val,batch_size = 1, shuffle = False)

test = customDataset([addData(size) for i in range(100)])
test_loader = DataLoader(test,batch_size = 1, shuffle = False)

# %%
featsz, hiddensz = 2, 1
model = LSTM(featsz, hiddensz)
# Define hyperparameters
n_epochs = 100
lr=.02

# Define Loss, Optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr,weight_decay = .0001)

# %%
for epoch in range(1, n_epochs + 1):
    model.train()
    hidden = torch.zeros(hiddensz),torch.zeros(hiddensz)
    losslist = []
    for d,t in train_loader:
        optimizer.zero_grad()
        output, hidden = model(d.squeeze(0),hidden)
        loss = criterion(output.sum(), t)
        
        loss.backward(retain_graph=True)
        losslist.append(loss.item())
        optimizer.step()
    model.eval()
    validationlist = []
    for d,t in val_loader:
        output,hidden = model(d.squeeze(0))
        loss = criterion(output.sum(), t)
        validationlist.append(loss.item())
    currval = np.mean(validationlist)
    print('Epoch: {}/{}.............'.format(epoch, n_epochs), end=' ')
    print("training: {:.4f},val Loss: {:.4f}".format(np.mean(losslist),currval))
# Out:
# Epoch: 1/100............. training: 0.0251,val Loss: 0.0244
# Epoch: 2/100............. training: 0.0250,val Loss: 0.0242
# Epoch: 3/100............. training: 0.0247,val Loss: 0.0240
# Epoch: 4/100............. training: 0.0245,val Loss: 0.0238
# Epoch: 5/100............. training: 0.0243,val Loss: 0.0237
# Epoch: 6/100............. training: 0.0241,val Loss: 0.0235
# Epoch: 58/100............. training: 0.0160,val Loss: 0.0160
# Epoch: 59/100............. training: 0.0158,val Loss: 0.0159
# Epoch: 60/100............. training: 0.0157,val Loss: 0.0158
# Epoch: 61/100............. training: 0.0156,val Loss: 0.0156
# Epoch: 62/100............. training: 0.0155,val Loss: 0.0155
# Epoch: 63/100............. training: 0.0153,val Loss: 0.0154
# Epoch: 64/100............. training: 0.0152,val Loss: 0.0153
# Epoch: 65/100............. training: 0.0151,val Loss: 0.0152
# Epoch: 66/100............. training: 0.0150,val Loss: 0.0151
# Epoch: 67/100............. training: 0.0148,val Loss: 0.0150
# Epoch: 68/100............. training: 0.0147,val Loss: 0.0149
# Epoch: 69/100............. training: 0.0146,val Loss: 0.0148
# Epoch: 70/100............. training: 0.0145,val Loss: 0.0147
# Epoch: 71/100............. training: 0.0143,val Loss: 0.0146
# Epoch: 72/100............. training: 0.0142,val Loss: 0.0145
# Epoch: 73/100............. training: 0.0141,val Loss: 0.0144
# Epoch: 74/100............. training: 0.0140,val Loss: 0.0143
# Epoch: 75/100............. training: 0.0139,val Loss: 0.0142
# Epoch: 76/100............. training: 0.0138,val Loss: 0.0141
# Epoch: 77/100............. training: 0.0136,val Loss: 0.0140
# Epoch: 78/100............. training: 0.0135,val Loss: 0.0139
# Epoch: 79/100............. training: 0.0134,val Loss: 0.0138
# Epoch: 80/100............. training: 0.0133,val Loss: 0.0137
# Epoch: 81/100............. training: 0.0132,val Loss: 0.0136
# Epoch: 82/100............. training: 0.0131,val Loss: 0.0135
# Epoch: 83/100............. training: 0.0130,val Loss: 0.0134
# Epoch: 84/100............. training: 0.0129,val Loss: 0.0133
# Epoch: 85/100............. training: 0.0128,val Loss: 0.0133
# Epoch: 86/100............. training: 0.0127,val Loss: 0.0132
# Epoch: 87/100............. training: 0.0126,val Loss: 0.0131
# Epoch: 88/100............. training: 0.0125,val Loss: 0.0130
# Epoch: 89/100............. training: 0.0124,val Loss: 0.0129
# Epoch: 90/100............. training: 0.0123,val Loss: 0.0128
# Epoch: 91/100............. training: 0.0122,val Loss: 0.0128
# Epoch: 92/100............. training: 0.0121,val Loss: 0.0127
# Epoch: 93/100............. training: 0.0120,val Loss: 0.0126
# Epoch: 94/100............. training: 0.0119,val Loss: 0.0125
# Epoch: 95/100............. training: 0.0118,val Loss: 0.0124
# Epoch: 96/100............. training: 0.0117,val Loss: 0.0124
# Epoch: 97/100............. training: 0.0116,val Loss: 0.0123
# Epoch: 98/100............. training: 0.0115,val Loss: 0.0122
# Epoch: 99/100............. training: 0.0114,val Loss: 0.0122
# Epoch: 100/100............. training: 0.0114,val Loss: 0.0121

# %%
model.eval()
predictions = []
labels = []
for d,t in test_loader:
    output,hidden = model(d.squeeze(0))
    predictions.append(output.sum())
    labels.append(t)
plt.figure(figsize=(15,12))
plt.plot(predictions,'r-')
plt.plot(labels,'b-')

# %% [markdown]
# # Multiplication

# %% [markdown]
# ### Now we'll be trying to learn to multiply. The goal is essentially the same except instead of adding the two numbers we multiply them.

# %%
def multData(size):
    size = np.random.choice(range(size,size+int(size/10)))
    inputs = torch.Tensor([[np.random.uniform(0,1),0] for i in range(size)])
    choice1 = np.random.choice(range(1,10))
    choice2 = list(range(1,int(size/2)))
    choice2.remove(choice1)
    choice2 = np.random.choice(choice2)
    inputs[choice1,1]=1
    inputs[choice2,1]=1
    label = inputs[:,0][inputs[:,1]==1].prod()
    return inputs,label

# %%
size = 20
train = customDataset([multData(size) for i in range(20)])
train_loader = DataLoader(train,batch_size = 1, shuffle = False)

val = customDataset([multData(size) for i in range(20)])
val_loader = DataLoader(val,batch_size = 1, shuffle = False)


test = customDataset([multData(size) for i in range(40)])
test_loader = DataLoader(test,batch_size = 1, shuffle = False)

# %%
featsz, hiddensz = 2, 1
model = LSTM(featsz, hiddensz)
# Define hyperparameters
n_epochs = 1000
lr=.02

# Define Loss, Optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr,weight_decay = .0001)

# %%
model.train()
minimum = 100
n_epochs = 100
for epoch in range(1, n_epochs + 1):
    model.train()
    hidden = torch.zeros(hiddensz),torch.zeros(hiddensz)
    
    losslist = []
    for d,t in train_loader:
        optimizer.zero_grad()
        output, hidden = model(d.squeeze(0),hidden)
        loss = criterion(hidden[0], t)
        loss.backward(retain_graph=True)
        losslist.append(loss.item())
        optimizer.step()
    model.eval()
    validationlist = []
    for d,t in val_loader:
        output,hidden = model(d.squeeze(0))
        loss = criterion(output.sum(), t)
        validationlist.append(loss.item())         
    currval = np.mean(validationlist)
    print('Epoch: {}/{}.............'.format(epoch, n_epochs), end=' ')
    print("training: {:.4f},val Loss: {:.4f}".format(np.mean(losslist),currval))
# Out:
# Epoch: 1/100............. training: 0.0266,val Loss: 46.7974
# Epoch: 2/100............. training: 0.0269,val Loss: 48.0931
# Epoch: 3/100............. training: 0.0267,val Loss: 45.9079
# Epoch: 4/100............. training: 0.0265,val Loss: 46.5966
# Epoch: 5/100............. training: 0.0264,val Loss: 45.6155
# Epoch: 6/100............. training: 0.0262,val Loss: 45.3818
# Epoch: 7/100............. training: 0.0261,val Loss: 44.7744
# Epoch: 8/100............. training: 0.0259,val Loss: 44.3199
# Epoch: 9/100............. training: 0.0258,val Loss: 43.7821
# Epoch: 10/100............. training: 0.0256,val Loss: 43.2533
# Epoch: 11/100............. training: 0.0255,val Loss: 42.6991
# Epoch: 12/100............. training: 0.0253,val Loss: 42.1257
# Epoch: 13/100............. training: 0.0252,val Loss: 41.5289
# Epoch: 14/100............. training: 0.0250,val Loss: 40.9056
# Epoch: 15/100............. training: 0.0248,val Loss: 40.2539
# Epoch: 16/100............. training: 0.0247,val Loss: 39.5718
# Epoch: 17/100............. training: 0.0245,val Loss: 38.8585
# Epoch: 18/100............. training: 0.0243,val Loss: 38.1144
# Epoch: 19/100............. training: 0.0242,val Loss: 37.3418
# Epoch: 20/100............. training: 0.0240,val Loss: 36.5455
# Epoch: 21/100............. training: 0.0239,val Loss: 35.7330
# Epoch: 22/100............. training: 0.0237,val Loss: 34.9144
# Epoch: 23/100............. training: 0.0235,val Loss: 34.1023
# Epoch: 24/100............. training: 0.0234,val Loss: 33.3089
# Epoch: 25/100............. training: 0.0232,val Loss: 32.5455
# Epoch: 26/100............. training: 0.0230,val Loss: 31.8206
# Epoch: 27/100............. training: 0.0228,val Loss: 31.1415
# Epoch: 28/100............. training: 0.0226,val Loss: 30.5155
# Epoch: 29/100............. training: 0.0224,val Loss: 29.9498
# Epoch: 80/100............. training: 0.0125,val Loss: 12.4102
# Epoch: 81/100............. training: 0.0127,val Loss: 23.7147
# Epoch: 82/100............. training: 0.0132,val Loss: 15.9884
# Epoch: 83/100............. training: 0.0108,val Loss: 16.0180
# Epoch: 84/100............. training: 0.0109,val Loss: 18.4118
# Epoch: 85/100............. training: 0.0126,val Loss: 10.6332
# Epoch: 86/100............. training: 0.0156,val Loss: 26.4084
# Epoch: 87/100............. training: 0.0152,val Loss: 21.8333
# Epoch: 88/100............. training: 0.0108,val Loss: 11.7534
# Epoch: 89/100............. training: 0.0122,val Loss: 22.8303
# Epoch: 90/100............. training: 0.0117,val Loss: 12.1271
# Epoch: 91/100............. training: 0.0110,val Loss: 19.5079
# Epoch: 92/100............. training: 0.0106,val Loss: 11.7867
# Epoch: 93/100............. training: 0.0110,val Loss: 19.6449
# Epoch: 94/100............. training: 0.0108,val Loss: 10.7076
# Epoch: 95/100............. training: 0.0119,val Loss: 22.3209
# Epoch: 96/100............. training: 0.0116,val Loss: 12.1306
# Epoch: 97/100............. training: 0.0109,val Loss: 18.4250
# Epoch: 98/100............. training: 0.0102,val Loss: 12.8319
# Epoch: 99/100............. training: 0.0099,val Loss: 14.8122
# Epoch: 100/100............. training: 0.0098,val Loss: 13.3002

# %%
model.eval()
predictions = []
labels = []
for d,t in test_loader:
    output,hidden = model(d.squeeze(0))
    predictions.append(output.sum())
    labels.append(t)
plt.figure(figsize=(15,12))
plt.plot(predictions,'r-')
plt.plot(labels,'b-')

# %% [markdown]
# # Questions
#
# 1. Why is addition easy for the LSTM to learn?
#
# The post-forget-gate cell-state data and the post-input-gate input data are literally added within the cell. This is analogous to the performance boost having an activation function and system which share the same function.
#
# 2. Why is multiplication harder for the LSTM to learn?
#
# No multiplcation step similar to the addition in question 1 is present. This means the model must learn to multiply using only its weights. Also, the order of operations no longer matters with multiplication (or addition). Approximating an order-dependent multiplcation function is much more difficult than approximating sequence-dependent data, as LSTMs are designed to do.

# %% [markdown]
# # Language Model
#
# ### Here we'll be teaching a model to produce shakespeare. It's a slow a task so we'll be using a more optimized and slightly changed LSTM to do it. The weight matrices have been stacked to reduce the number of matrix multiplications performed and the output now has its own weight matrix. You just need to fill in the function with the correct part of the gates matrix.

# %%
class betterLSTM(nn.Module):
    def __init__(self,inputsz,hiddensz):
        super().__init__()
        self.inputsz=inputsz
        self.hiddensz=hiddensz
        
        #input gate
        self.Wx =  Parameter(torch.Tensor(hiddensz*4,inputsz))
        self.Wh = Parameter(torch.Tensor(hiddensz*4,hiddensz))
        self.Wy = Parameter(torch.Tensor(inputsz,hiddensz))
        self.by = Parameter(torch.Tensor(inputsz,1))
        self.b = Parameter(torch.Tensor(hiddensz*4,1))
        #paramter initialization
        for p in self.parameters():
            if p.data.ndimension()>=2:
                nn.init.xavier_uniform_(p.data)
            else:
                nn.init.zeros_(p.data)
                
    def forward(self,x,initstates=None):
        m = len(x)
        hidden_seq = []
        if initstates is None:
            ht,ct = torch.zeros(self.hiddensz,1),torch.zeros(self.hiddensz,1)
        else:
            ht,ct = initstates
        xt = x
        gates = self.Wx@xt+self.Wh@ht+self.b
        #print(gates.size(), self.hiddensz, self.hiddensz*4, self.inputsz)
        
        # The assignment of a gate to a slice doesn't matter as long as I'm consistent.
        it = torch.sigmoid(gates[self.hiddensz * 0:self.hiddensz * 1]) ##################### TO DO #####################
        ft = torch.sigmoid(gates[self.hiddensz * 1:self.hiddensz * 2]) ##################### TO DO #####################
        gt = torch.tanh(   gates[self.hiddensz * 2:self.hiddensz * 3]) ##################### TO DO #####################
        ot = torch.sigmoid(gates[self.hiddensz * 3:self.hiddensz * 4]) ##################### TO DO #####################
        ct = ft*ct+it*gt
        ht = ot*torch.tanh(ct)
                    
        output = self.Wy@ht+self.by
        return output, (ht,ct)

# %% [markdown]
# ### Here we load the data and transform it into one-hot vectors.

# %%
file = open('clean_shakespeare.txt','r')
text = file.read()
letters = 'abcdefghijklmnopqrstuvwxyz '
# one hot encode characters
char_dict = {}
for i,char in enumerate(letters):
    vec = torch.zeros(27)
    vec[i] += 1
    char_dict[char] = vec

total_data = 40000

D = []
for i in range(total_data):
    x = text[i]
    y = text[i+1]
    D.append((char_dict[x],char_dict[y]))


featsz, hiddensz = 27, 64
model = betterLSTM(featsz, hiddensz)

# %% [markdown]
# ### This function generates text with our model. You can try different seeds to see what you get. "rand" influences randomness in the text generation and "size" determines how many characters will be produced.

# %%
seed = 'to be or not to be that is the question'
def text_gen(model,seed,rand=5,h_size=32,size=100):
    n = len(seed)
    one_hot = torch.zeros(n,27)
    for i in range(n):
        one_hot[i] = char_dict[seed[i]]
    hidden = torch.zeros(hiddensz,1),torch.zeros(hiddensz,1)
    last_char = ''
    for vec in one_hot:
        y_hat,hidden = model(vec.unsqueeze(1),hidden)
        out = y_hat.permute((1,0))
    char = letters[torch.argmax(out)]
    seed += char
    for i in range(size):
        last_char = char
        y_hat,hidden = model(char_dict[last_char].unsqueeze(1),hidden)
        out = y_hat.permute((1,0))
        if last_char == ' ':
            best = torch.argsort(out)
            best = best[-rand:]
            char = np.random.choice(best.squeeze(0))
            char = letters[char]
        else:
            char = torch.argmax(out)
            char = letters[char]
        seed += char
    return seed

# %%
train = customDataset(D)
train_loader = DataLoader(train,batch_size = 1, shuffle = False)
lr = .001
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ### We truncated the back propogation to speed things up. You can try different values of truncation to see how it performs.
#
# ### DB COMMENT: Is this really truncation as we usually understand it?  It looks like we're just ignoring most of the training data via this "truncation term"...

# %%
n_epochs = 30
truncate = 32
for epoch in range(1, n_epochs + 1):
    model.train()
    hidden = torch.zeros(hiddensz,1),torch.zeros(hiddensz,1)
    losslist = []
    i = 1
    loss = 0
    for d,t in train_loader:
        if i%truncate==0:
            loss.backward(retain_graph=True)
            optimizer.step()
            optimizer.zero_grad()
            loss = 0
            hidden = (hidden[0].data,hidden[1].data)
        output, hidden = model(d.permute((1,0)),hidden)
        loss += criterion(output.permute((1,0)),t.argmax(dim=1))
        losslist.append(loss.item())
        i += 1
    print('Epoch: {}/{}.............'.format(epoch, n_epochs), end=' ')
    print("training: {:.4